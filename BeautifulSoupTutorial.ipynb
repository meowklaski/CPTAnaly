# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
home = 'https://capcomprotour.com/'

# %%
import urllib2
response = urllib2.urlopen('https://capcomprotour.com/schedule/')
html_doc = response.read()

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')

# %%
response = urllib2.urlopen(home+'/schedule/')
soup = BeautifulSoup(response.read(), 'html.parser')

# %%
for i in soup.find_all('br')[6:]:
    try:
        print i.contents[1].strip()
    except IndexError:
        print i.contents
# Out:
# 02-27-2015 - 03-01-2015
# 03-07-2015 - 03-07-2015
# 03-15-2015 - 03-15-2015
# 03-20-2015 - 03-22-2015
# 04-03-2015 - 04-05-2015
# 04-04-2015 - 04-05-2015
# 04-24-2015 - 04-26-2015
# 04-25-2015 - 04-25-2015
# 05-04-2015 - 05-04-2015
# 05-08-2015 - 05-10-2015
# 05-22-2015 - 05-24-2015
# 05-22-2015 - 05-24-2015
# 05-29-2015 - 05-31-2015
# 06-13-2015 - 06-16-2015
# 06-19-2015 - 06-21-2015
# 06-26-2015 - 06-28-2015
# 07-17-2015 - 07-19-2015
# 07-31-2015 - 08-01-2015
# 08-08-2015 - 08-09-2015
# 08-08-2015 - 08-09-2015
# 08-22-2015 - 08-22-2015
# 08-28-2015 - 08-30-2015
# 08-29-2015 - 08-29-2015
# 09-04-2015 - 09-06-2015
# 09-04-2015 - 09-06-2015
# 09-11-2015 - 09-13-2015
# 09-12-2015 - 09-12-2015
# 09-20-2015 - 09-20-2015
# 09-24-2015 - 09-26-2015
# 09-24-2015 - 09-27-2015
# 09-25-2015 - 09-27-2015
# 10-03-2015 - 10-04-2015
# 10-03-2015 - 10-04-2015
# 10-09-2015 - 10-11-2015
# 10-10-2015 - 10-12-2015
# 10-17-2015 - 10-17-2015
# 10-23-2015 - 10-25-2015
# 10-24-2015 - 10-25-2015
# ...

# %%
len(soup.find_all('br')[6:])
# Out:
# 40

# %%
print soup.prettify()
# Out:
# <!DOCTYPE doctype html>
# <!--[if IEMobile 7 ]> <html lang="en-US" prefix="og: http://ogp.me/ns#"class="no-js iem7"> <![endif]-->
# <!--[if lt IE 7 ]> <html lang="en-US" prefix="og: http://ogp.me/ns#" class="no-js ie6"> <![endif]-->
# <!--[if IE 7 ]>    <html lang="en-US" prefix="og: http://ogp.me/ns#" class="no-js ie7"> <![endif]-->
# <!--[if IE 8 ]>    <html lang="en-US" prefix="og: http://ogp.me/ns#" class="no-js ie8"> <![endif]-->
# <!--[if (gte IE 9)|(gt IEMobile 7)|!(IEMobile)|!(IE)]><!-->
# <html class="no-js" lang="en-US" prefix="og: http://ogp.me/ns#">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8">
#    <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#     <title>
#      Schedule | Capcom Pro Tour
#     </title>
#     <link href="https://capcomprotour.com/wp-content/plugins/sitepress-multilingual-cms/res/css/language-selector.css?v=3.2.7" media="all" rel="stylesheet" type="text/css"/>
# ...

# %%
for i in soup.find_all('a'):
    if i.string == 'View Results':
        print(i.string)
        print i.get('href')
# Out:
# View Results
# http://capcomprotour.com/cannes-winter-clash-results/
# View Results
# http://capcomprotour.com/abuget-cup-2015-results/
# View Results
# http://capcomprotour.com/nine-states-tournament-2015-results/
# View Results
# http://capcomprotour.com/premier-tournament-final-round-18-results-rzrxian-qualifies-for-capcom-cup-2015/
# View Results
# http://capcomprotour.com/premier-tournament-norcal-regionals-2015-results-mczdaigo-umehara-qualifies-for-capcom-cup-2015/
# View Results
# http://capcomprotour.com/premier-tournament-hypespotting-4-results/
# View Results
# http://capcomprotour.com/northwest-majors-7-results/
# View Results
# http://capcomprotour.com/double-elimination-results/
# View Results
# http://capcomprotour.com/kvo-2015-results/
# View Results
# http://capcomprotour.com/texas-showdown-2015-results/
# View Results
# http://capcomprotour.com/ranking-tournament-combo-breaker-2015-results/
# View Results
# ...

# %%
soup.a.attrs
# Out:
# {u'class': [u'aga-brand'],
#  u'href': u'https://capcomprotour.com',
#  u'id': u'logo',
#  u'title': u'Ultra Street FIghter IV'}

# %%
data = []
for entry in soup.find_all('tr')[1:]:
    data.append([i.contents[0] for i in entry.contents[::2]])

# %%
entry
# Out:
# <tr><td>1st</td>
# <td> /r/Kappa|Poongko</td>
# <td>Seth/El Fuerte </td>
# <td> 128</td>
# </tr>

# %%
data = [i.contents[0] for i in entry.contents[::2]]

# %%
data
# Out:
# [[u'1st', u' /r/Kappa|Poongko', u'Seth/El Fuerte ', u' 128'],
#  [u'2nd', u' HORI|Sako', u' Elena/Evil Ryu/Gen', u' 64'],
#  [u'3rd', u' /r/Kappa|Infiltration', u' Decapre/Akuma/Hakan', u' 32'],
#  [u'4th', u' JehoSan', u' Cammy/Decapre/Guile', u' 16'],
#  [u'5th', u' Tonpy', u' C.Viper', u' 8'],
#  [u'5th', u'\xa0GL|Valmaster', u' Chun-Li', u' 8'],
#  [u'7th', u'\xa0Dieminion', u' Guile', u' 4'],
#  [u'7th', u'\xa0Qanba|Xiao Hai', u' Cammy', u' 4'],
#  [u'9th', u'\xa0UM|ImStillDaDaddy', u' Guile', u' 2'],
#  [u'9th', u'\xa0Ninja Shakz', u' Abel', u' 2'],
#  [u'9th', u'\xa0DIG|Prodigal Son', u' Sagat/Ryu/Abel', u' 2'],
#  [u'9th', u'\xa0RZR CG|Problem X', u' C.Viper', u' 2'],
#  [u'13th', u' F-Word', u' Ibuki', u' 1'],
#  [u'13th', u'\xa0RIZE|Pro Fluke', u' El Fuerte', u' 1'],
#  [u'13th', u'\xa0Daddy|Renegad', u' Poison', u' 1'],
#  [u'13th', u'\xa0BX3|Phenom', u' M.Bison', u' 1']]

# %%
data
# Out:
# [<td>1st</td>,
#  u'\n',
#  <td> /r/Kappa|Poongko</td>,
#  u'\n',
#  <td>Seth/El Fuerte </td>,
#  u'\n',
#  <td> 128</td>,
#  u'\n']

# %%
import urllib2
response = urllib2.urlopen('http://capcomprotour.com/nine-states-tournament-2015-results/')
html_doc = response.read()

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')

# %%
data = []
for entry in soup.find_all('tr')[1:]:
    data.append([i.contents[0] for i in entry.contents[::2]])

# %%
data
# Out:
# [[u'1st', u' /r/Kappa|Infiltration', u' Decapre/Akuma', u' 128'],
#  [u'2nd', u' /r/Kappa|Poongko', u' Seth/El Fuerte', u' 64'],
#  [u'3rd', u' YBK|Shiro', u' Abel', u' 32'],
#  [u'4th', u' Inco', u' Rufus', u' 16'],
#  [u'5th', u' Nishikin', u' Blanka', u' 8'],
#  [u'5th', u' Gattikun', u' Sagat', u' 8'],
#  [u'7th', u' Kindo', u' Guy', u' 4'],
#  [u'7th', u' Mizoteru', u' Blanka', u' 4'],
#  [u'9th', u' RZR|Itazan', u' Zangief', u' 2'],
#  [u'9th', u' Chiaki', u' Chun-Li', u' 2'],
#  [u'9th', u' Anton', u' Gouken', u' 2'],
#  [u'9th', u' Misse', u' Makoto', u' 2'],
#  [u'13th', u' Akimo', u' Elena', u' 1'],
#  [u'13th', u' Hikarin', u' Oni', u' 1'],
#  [u'13th', u' FGC/pepeday', u' El Fuerte', u' 1'],
#  [u'13th', u' Kawaguchi', u' Rose', u' 1']]
