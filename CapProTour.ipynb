# %%
__author__ = "Ryan Soklaski"
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns
import pandas as pd

# %%
player_names = [
    'Momochi',
    'Poongko',
    'Itabashi Zangief',
    'Fuudo',
    'HumanBomb',
    'Mago',
    'Dark Jiewa',
    'Xian',
    'Valmaster',
    'Nemo',
    'Dashio',
    'Gamerbee',
    'Gackt',
    'Snake Eyez',
    'Keoma',
    'Infiltration',
    'Justin Wong',
    'Tonpy',
    'Tokido',
    'Shiro',
    'Daigo',
    'Dieminion',
    'Bonchan',
    'Xiao Hai',
    'Nuckledu',
    'Luffy',
    'Problem X',
    'Kazunoko',
    '801 Strider'
]

# %%
len(player_names)
# Out:
# 29

# %%
import urllib2
response = urllib2.urlopen('http://capcomprotour.com/cannes-winter-clash-results/')
html = response.read()

# %%
html
# Out:
# '<!doctype html>  \n\n<!--[if IEMobile 7 ]> <html lang="en-US" prefix="og: http://ogp.me/ns#"class="no-js iem7"> <![endif]-->\n<!--[if lt IE 7 ]> <html lang="en-US" prefix="og: http://ogp.me/ns#" class="no-js ie6"> <![endif]-->\n<!--[if IE 7 ]>    <html lang="en-US" prefix="og: http://ogp.me/ns#" class="no-js ie7"> <![endif]-->\n<!--[if IE 8 ]>    <html lang="en-US" prefix="og: http://ogp.me/ns#" class="no-js ie8"> <![endif]-->\n<!--[if (gte IE 9)|(gt IEMobile 7)|!(IEMobile)|!(IE)]><!--><html lang="en-US" prefix="og: http://ogp.me/ns#" class="no-js"><!--<![endif]-->\n\t\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n\t\t\n\t\t<title>Cannes Winter Clash Results | Capcom Pro Tour</title>\n\n<link rel="stylesheet" href="http://capcomprotour.com/wp-content/plugins/sitepress-multilingual-cms/res/css/language-selector.css?v=3.2.7" type="text/css" media="all" />\n\t\t\t\t\n\t\t<meta name="viewport" content="width=device-width, init
# ...

# %%
from bs4 import BeautifulSoup
